# %%
import urllib
from PIL import Image
import json
import pandas as pd

# %% [markdown]
# # Download imagery from Google Maps API

# %%
# get API key
API_KEY = 'AIzaSyBJfYqFqha9snvKzESzsVOpsHPg-T17MgU'

# %%
class GoogleMapDownloader:
    """
        A class which generates high resolution google maps images given
        a longitude, latitude and zoom level
    """
    def __init__(self, lat, lng, zoom=None):
        """
            GoogleMapDownloader Constructor
            Args:
                lat:    The latitude of the location required
                lng:    The longitude of the location required
                zoom:   The zoom level of the location required, ranges from 0 - 23
                        defaults to 12
        """
        self._lat = lat
        self._lng = lng
        self._zoom = zoom
        # self._name = name

    def generateImage(self):
        

        url ="https://maps.googleapis.com/maps/api/staticmap?center="+str(self._lat)+","+str(self._lng)+"&zoom="+str(self._zoom)+f"&size=640x640&maptype=satellite&key={API_KEY}"
        print(url)
        current_tile = "high_res"
        urllib.request.urlretrieve(url, current_tile)
        im = Image.open(current_tile)
        
        return im

# %% [markdown]
# ## Load data to get coordinates

# %%
locations = pd.read_csv('data/EP_LBA_mapping_anonymised.csv')
locations
# Out:
#           ID Region       avg          total  duplicate_group   Latitude  \
# 0          0  South  1.689252   29597.377367             1063  30.520049
# 1          1  South  1.689252   29597.377367             1063  30.520049
# 2          2  South       NaN            NaN                0  30.222595
# 3          3  South       NaN            NaN                0  30.222595
# 4          4  South       NaN            NaN                0  29.984090
# ...      ...    ...       ...            ...              ...        ...
# 81634  81634    NaN  9.913880  325730.444263             5774        NaN
# 81635  81635    NaN  2.507944   82401.003913             2450        NaN
# 81636  81636    NaN  4.594964  150972.123956             3777        NaN
# 81637  81637    NaN  4.879646  160325.644894             3927        NaN
# 81638  81638    NaN  4.986795  163846.124357             3984        NaN
#
#        Longitude
# 0     -91.153196
# 1     -91.153196
# 2     -91.056028
# 3     -91.056028
# ...

# %%
# sample images by taking the first 1000 locations
locations = locations.iloc[:1000]
locations
# Out:
#       ID Region       avg          total  duplicate_group   Latitude  \
# 0      0  South  1.689252   29597.377367             1063  30.520049
# 1      1  South  1.689252   29597.377367             1063  30.520049
# 2      2  South       NaN            NaN                0  30.222595
# 3      3  South       NaN            NaN                0  30.222595
# 4      4  South       NaN            NaN                0  29.984090
# ..   ...    ...       ...            ...              ...        ...
# 995  995  South       NaN            NaN                0  29.994202
# 996  996  South       NaN            NaN                0  29.994202
# 997  997    NaN  8.329024  273658.423633             5357        NaN
# 998  998    NaN  2.984312   98052.552596             2773        NaN
# 999  999  South  1.996649   65601.911118             2016  29.212829
#
#      Longitude
# 0   -91.153196
# 1   -91.153196
# 2   -91.056028
# 3   -91.056028
# 4   -92.102203
# ..         ...
# 995 -93.899954
# ...

# %%
for index, row in locations.iterrows():
    print(row['ID'])
    lat = row['Latitude']
    lon = row['Longitude']
    ID = row['ID']
    resolution = 17  # this is an important hyperparameter, as it determines the resolution of the images / the classifier
    gmd = GoogleMapDownloader(lat,lon, resolution)
    img = gmd.generateImage()
    img.save(f'data/res{resolution}/{ID}.png')
# Out:
# 0
# https://maps.googleapis.com/maps/api/staticmap?center=30.520049,-91.153196&zoom=17&size=640x640&maptype=satellite&key=AIzaSyBJfYqFqha9snvKzESzsVOpsHPg-T17MgU
# 1
# https://maps.googleapis.com/maps/api/staticmap?center=30.520049,-91.153196&zoom=17&size=640x640&maptype=satellite&key=AIzaSyBJfYqFqha9snvKzESzsVOpsHPg-T17MgU
# 2
# https://maps.googleapis.com/maps/api/staticmap?center=30.222595,-91.056028&zoom=17&size=640x640&maptype=satellite&key=AIzaSyBJfYqFqha9snvKzESzsVOpsHPg-T17MgU
# 3
# https://maps.googleapis.com/maps/api/staticmap?center=30.222595,-91.056028&zoom=17&size=640x640&maptype=satellite&key=AIzaSyBJfYqFqha9snvKzESzsVOpsHPg-T17MgU
# 4
# https://maps.googleapis.com/maps/api/staticmap?center=29.98409,-92.102203&zoom=17&size=640x640&maptype=satellite&key=AIzaSyBJfYqFqha9snvKzESzsVOpsHPg-T17MgU
# 5
# https://maps.googleapis.com/maps/api/staticmap?center=29.98409,-92.102203&zoom=17&size=640x640&maptype=satellite&key=AIzaSyBJfYqFqha9snvKzESzsVOpsHPg-T17MgU
# 6
# ...

# %%
# show image
img.show()
